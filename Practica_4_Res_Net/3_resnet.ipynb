# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Number of points for this notebook:</b> 2
# <br>
# <b>Deadline:</b> November 4, 2025 (Tuesday) 23:59
# </div>
#
# # Exercise 3.1. Convolutional networks. ResNet.
#
# # DO NOT MODIFY ANY Test Cells.
#
# In this week, your goal is to implement a convolutional neural network with a ResNet architecture [(He et al, 2016)](https://arxiv.org/abs/1512.03385).

# %%
skip_training = True  # Set this flag to True before validation and submission

# %%
# During evaluation, this cell sets skip_training to True
# skip_training = True

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import torch
import torchvision
import torchvision.transforms as transforms

import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import tools
import tests

# %%
# When running on your own computer, you can specify the data directory by:
# data_dir = tools.select_data_dir('/your/local/data/directory')
data_dir = tools.select_data_dir()
# Out:
# The data directory is ../data

# %%
# Select the device for training (use GPU if you have one)
#device = torch.device('cuda:0')
device = torch.device('cpu')

# %%
if skip_training:
    # The models are always evaluated on CPU
    device = torch.device("cpu")

# %% [markdown]
# ## FashionMNIST dataset
#
# Let us use the FashionMNIST dataset. It consists of 60,000 training images of 10 classes: 'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot'.

# %%
transform = transforms.Compose([
    transforms.ToTensor(),  # Transform to tensor
    transforms.Normalize((0.5,), (0.5,))  # Scale images to [-1, 1]
])

trainset = torchvision.datasets.FashionMNIST(root=data_dir, train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root=data_dir, train=False, download=True, transform=transform)

classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal',
           'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

trainloader = torch.utils.data.DataLoader(trainset, batch_size=32, shuffle=True)
testloader = torch.utils.data.DataLoader(testset, batch_size=5, shuffle=False)

# %% [markdown]
# ## ResNet
#
# We create a network with an architecure inspired by [ResNet](https://arxiv.org/pdf/1512.03385.pdf).
#
# ### ResNet block
# Our ResNet consists of blocks with two convolutional layers and a skip connection.
#
# In the most general case, our implementation should have:
#
# <img src="resnet_block_04.png" width=220 style="float: right;">
#
# * Two convolutional layers with:
#     * 3x3 kernel
#     * no bias terms
#     * padding with one pixel on both sides
#     * 2d batch normalization after each convolutional layer.
#
# * **The first convolutional layer also (optionally) has:**
#     * different number of input channels and output channels
#     * change of the resolution with stride.
#
# * The skip connection:
#     * simply copies the input if the resolution and the number of channels do not change.
#     * if either the resolution or the number of channels change, the skip connection should have one convolutional layer with:
#         * 1x1 convolution **without bias**
#         * change of the resolution with stride (optional)
#         * different number of input channels and output channels (optional)
#     * if either the resolution or the number of channels change, the 1x1 convolutional layer is followed by 2d batch normalization.
#
# * The ReLU nonlinearity is applied after the first convolutional layer and at the end of the block.
#
# <div class="alert alert-block alert-warning">
# <b>Note:</b> Batch normalization is expected to be right after a convolutional layer.
# </div>

# %% [markdown]
# <img src="resnet_blocks_123.png" width=650 style="float: top;">
#
# The implementation should also handle specific cases such as:
#
# Left: The number of channels and the resolution do not change.
# There are no computations in the skip connection.
#
# Middle: The number of channels changes, the resolution does not change.
#
# Right: The number of channels does not change, the resolution changes.

# %% [markdown]
# Your task is to implement this block. You should use the implementations of layers in `nn.Conv2d`, `nn.BatchNorm2d` as the tests rely on those implementations.

# %%
class Block(nn.Module):
    def __init__(self, in_channels, out_channels, stride=1):
        """
        Args:
          in_channels (int):  Number of input channels.
          out_channels (int): Number of output channels.
          stride (int):       Controls the stride.
        """
        super(Block, self).__init__()
        self.block_before_connection = nn.Sequential(nn.Conv2d(in_channels=in_channels,out_channels=out_channels,kernel_size=(3,3),stride=stride,padding=(1,1),bias=False),
                                                     nn.BatchNorm2d(out_channels),
                                                     nn.ReLU(inplace=False),
                                                     nn.Conv2d(in_channels=out_channels,out_channels=out_channels,kernel_size=(3,3),stride=1,padding=(1,1),bias=False),
                                                     nn.BatchNorm2d(out_channels))
        self.connection_block = nn.Sequential(nn.Conv2d(in_channels=in_channels,out_channels=out_channels,kernel_size=(1,1),stride=stride,bias=False),
                                              nn.BatchNorm2d(out_channels)) if (in_channels != out_channels) or (stride != 1) else nn.Identity()
        self.final_layer = nn.ReLU()
        

    def forward(self, x):
        b1 = self.block_before_connection(x)
        b2 = self.connection_block(x)
        b = b1 + b2 
        f = self.final_layer(b)
        return f

# %%
def test_Block_shapes():

    # The number of channels and resolution do not change
    batch_size = 20
    x = torch.zeros(batch_size, 16, 28, 28)
    block = Block(in_channels=16, out_channels=16)
    y = block(x)
    assert y.shape == torch.Size([batch_size, 16, 28, 28]), "Bad shape of y: y.shape={}".format(y.shape)

    # Increase the number of channels
    block = Block(in_channels=16, out_channels=32)
    y = block(x)
    assert y.shape == torch.Size([batch_size, 32, 28, 28]), "Bad shape of y: y.shape={}".format(y.shape)

    # Decrease the resolution
    block = Block(in_channels=16, out_channels=16, stride=2)
    y = block(x)
    assert y.shape == torch.Size([batch_size, 16, 14, 14]), "Bad shape of y: y.shape={}".format(y.shape)

    # Increase the number of channels and decrease the resolution
    block = Block(in_channels=16, out_channels=32, stride=2)
    y = block(x)
    assert y.shape == torch.Size([batch_size, 32, 14, 14]), "Bad shape of y: y.shape={}".format(y.shape)

    print('Success')

test_Block_shapes()
# Out:
# Success

# %%
tests.test_Block(Block)
tests.test_Block_relu(Block)
tests.test_Block_batch_norm(Block)
# Out:
# Success
# Success
# Success

# %% [markdown]
# ### Group of blocks
#
# ResNet consists of several groups of blocks. The first block in a group may change the number of channels (often multiples the number by 2) and subsample (using strides).
#
# <img src="resnet_group.png" width=500 style="float: left;">

# %%
# We implement a group of blocks in this cell
class GroupOfBlocks(nn.Module):
    def __init__(self, in_channels, out_channels, n_blocks, stride=1):
        super(GroupOfBlocks, self).__init__()

        first_block = Block(in_channels, out_channels, stride)
        other_blocks = [Block(out_channels, out_channels) for _ in range(1, n_blocks)]
        self.group = nn.Sequential(first_block, *other_blocks)

    def forward(self, x):
        return self.group(x)

# %%
# Let's print a block
group = GroupOfBlocks(in_channels=10, out_channels=20, n_blocks=3)
print(group)
# Out:
# GroupOfBlocks(
#   (group): Sequential(
#     (0): Block(
#       (block_before_connection): Sequential(
#         (0): Conv2d(10, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (connection_block): Sequential(
#         (0): Conv2d(10, 20, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (final_layer): ReLU()
#     )
#     (1): Block(
#       (block_before_connection): Sequential(
#         (0): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (connection_block): Identity()
#       (final_layer): ReLU()
#     )
#     (2): Block(
#       (block_before_connection): Sequential(
#         (0): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (1): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(20, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (4): BatchNorm2d(20, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (connection_block): Identity()
#       (final_layer): ReLU()
#     )
#   )
# )

# %% [markdown]
# ### ResNet
#
# Next we implement a ResNet with the following architecture. It contains three groups of blocks, each group having two basic blocks.
#
# <img src="resnet.png" width=900 style="float: left;">

# %% [markdown]
# The cell below contains the implementation of our ResNet.

# %%
class ResNet(nn.Module):
    def __init__(self, n_blocks, n_channels=64, num_classes=10):
        """
        Args:
          n_blocks (list):   A list with three elements which contains the number of blocks in 
                             each of the three groups of blocks in ResNet.
                             For instance, n_blocks = [2, 4, 6] means that the first group has two blocks,
                             the second group has four blocks and the third one has six blocks.
          n_channels (int):  Number of channels in the first group of blocks.
          num_classes (int): Number of classes.
        """
        assert len(n_blocks) == 3, "The number of groups should be three."
        super(ResNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=n_channels, kernel_size=5, stride=1, padding=2, bias=False)
        self.bn1 = nn.BatchNorm2d(n_channels)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        self.group1 = GroupOfBlocks(n_channels, n_channels, n_blocks[0])
        self.group2 = GroupOfBlocks(n_channels, 2*n_channels, n_blocks[1], stride=2)
        self.group3 = GroupOfBlocks(2*n_channels, 4*n_channels, n_blocks[2], stride=2)

        self.avgpool = nn.AvgPool2d(kernel_size=4, stride=1)
        self.fc = nn.Linear(4*n_channels, num_classes)

        # Initialize weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, np.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()

    def forward(self, x, verbose=False):
        """
        Args:
          x of shape (batch_size, 1, 28, 28): Input images.
          verbose: True if you want to print the shapes of the intermediate variables.
        
        Returns:
          y of shape (batch_size, 10): Outputs of the network.
        """
        if verbose: print(x.shape)
        x = self.conv1(x)
        if verbose: print('conv1:  ', x.shape)
        x = self.bn1(x)
        if verbose: print('bn1:    ', x.shape)
        x = self.relu(x)
        if verbose: print('relu:   ', x.shape)
        x = self.maxpool(x)
        if verbose: print('maxpool:', x.shape)

        x = self.group1(x)
        if verbose: print('group1: ', x.shape)
        x = self.group2(x)
        if verbose: print('group2: ', x.shape)
        x = self.group3(x)
        if verbose: print('group3: ', x.shape)

        x = self.avgpool(x)
        if verbose: print('avgpool:', x.shape)

        x = x.view(-1, self.fc.in_features)
        if verbose: print('x.view: ', x.shape)
        x = self.fc(x)
        if verbose: print('out:    ', x.shape)

        return x

# %%
def test_ResNet_shapes():
    # Create a network with 2 block in each of the three groups
    n_blocks = [2, 2, 2]  # number of blocks in the three groups
    net = ResNet(n_blocks, n_channels=10)
    net.to(device)

    # Feed a batch of images from the training data to test the network
    with torch.no_grad():
        images, labels = next(iter(trainloader))
        images = images.to(device)
        print('Shape of the input tensor:', images.shape)

        y = net.forward(images, verbose=True)
        print(y.shape)
        assert y.shape == torch.Size([trainloader.batch_size, 10]), "Bad shape of y: y.shape={}".format(y.shape)

    print('Success')

test_ResNet_shapes()
# Out:
# Shape of the input tensor: torch.Size([32, 1, 28, 28])
# torch.Size([32, 1, 28, 28])
# conv1:   torch.Size([32, 10, 28, 28])
# bn1:     torch.Size([32, 10, 28, 28])
# relu:    torch.Size([32, 10, 28, 28])
# maxpool: torch.Size([32, 10, 14, 14])
# group1:  torch.Size([32, 10, 14, 14])
# group2:  torch.Size([32, 20, 7, 7])
# group3:  torch.Size([32, 40, 4, 4])
# avgpool: torch.Size([32, 40, 1, 1])
# x.view:  torch.Size([32, 40])
# out:     torch.Size([32, 10])
# torch.Size([32, 10])
# Success

# %% [markdown]
# # Train the network

# %%
# This function computes the accuracy on the test dataset
def compute_accuracy(net, testloader):
    net.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
    return correct / total

# %% [markdown]
# ### Training loop
#
# In the cell below, implement the training loop. The recommended hyperparameters:
# * Adam optimizer with learning rate 0.01.
# * Cross-entropy loss. Note that we did not use softmax nonlinearity in the final layer of our network. Therefore, we need to use a loss function with log_softmax implemented, such as [`nn.CrossEntropyLoss`](https://pytorch.org/docs/stable/nn.html#torch.nn.CrossEntropyLoss).
# * Number of epochs: 10
#
# We recommend you to use function `compute_accuracy()` defined above to track the accaracy during training. The test accuracy should be above 0.9.
#
# **Note: function `compute_accuracy()` sets the network into the evaluation mode which changes the way the batch statistics are computed in batch normalization. You need to set the network into the training mode (by calling `net.train()`) when you want to perform training.**

# %%
# Create the network
n_blocks = [2, 2, 2]  # number of blocks in the three groups
net = ResNet(n_blocks, n_channels=16)
net.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(1, 16, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (group1): GroupOfBlocks(
#     (group): Sequential(
#       (0): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Identity()
#         (final_layer): ReLU()
#       )
#       (1): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Identity()
#         (final_layer): ReLU()
#       )
#     )
#   )
#   (group2): GroupOfBlocks(
#     (group): Sequential(
#       (0): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Sequential(
#           (0): Conv2d(16, 32, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (final_layer): ReLU()
#       )
#       (1): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Identity()
#         (final_layer): ReLU()
#       )
#     )
#   )
#   (group3): GroupOfBlocks(
#     (group): Sequential(
#       (0): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Sequential(
#           (0): Conv2d(32, 64, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (final_layer): ReLU()
#       )
#       (1): Block(
#         (block_before_connection): Sequential(
#           (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU()
#           (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (connection_block): Identity()
#         (final_layer): ReLU()
#       )
#     )
#   )
#   (avgpool): AvgPool2d(kernel_size=4, stride=1, padding=0)
#   (fc): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# Implement the training loop in this cell
num_epochs = 10
net.train()
if not skip_training:
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(params=net.parameters(),lr=0.001) 
    for i in range(num_epochs): 
        for images,labels in trainloader: 
            images = images.to(device)
            labels = labels.to(device)
            outputs = net(images)
            loss = criterion(outputs,labels)
            #backward and optimize: 
            optimizer.zero_grad()
            loss.backward()
            optimizer.step() 
            print(f'Epoch {i} and the loss is: {loss}')
# Out:
# Epoch 0 and the loss is: 0.1873960644006729
# Epoch 0 and the loss is: 0.2283952832221985
# Epoch 0 and the loss is: 0.16189701855182648
# Epoch 0 and the loss is: 0.11711727827787399
# Epoch 0 and the loss is: 0.20370851457118988
# Epoch 0 and the loss is: 0.1698226034641266
# Epoch 0 and the loss is: 0.14598551392555237
# Epoch 0 and the loss is: 0.055675335228443146
# Epoch 0 and the loss is: 0.30347058176994324
# Epoch 0 and the loss is: 0.34061720967292786
# Epoch 0 and the loss is: 0.0771416425704956
# Epoch 0 and the loss is: 0.09346146136522293
# Epoch 0 and the loss is: 0.17943891882896423
# Epoch 0 and the loss is: 0.19757770001888275
# Epoch 0 and the loss is: 0.15498441457748413
# Epoch 0 and the loss is: 0.10028422623872757
# Epoch 0 and the loss is: 0.10056465864181519
# Epoch 0 and the loss is: 0.06737574934959412
# Epoch 0 and the loss is: 0.09721077233552933
# Epoch 0 and the loss is: 0.12630343437194824
# Epoch 0 and the loss is: 0.15981191396713257
# Epoch 0 and the loss is: 0.13087493181228638
# Epoch 0 and the loss is: 0.21235217154026031
# Epoch 0 and the loss is: 0.20290593802928925
# Epoch 0 and the loss is: 0.27006763219833374
# Epoch 0 and the loss is: 0.070468008518219
# Epoch 0 and the loss is: 0.08955146372318268
# Epoch 0 and the loss is: 0.10473500192165375
# Epoch 0 and the loss is: 0.1859680861234665
# Epoch 0 and the loss is: 0.0572226382791996
# Epoch 0 and the loss is: 0.06789679825305939
# Epoch 0 and the loss is: 0.10048161447048187
# Epoch 0 and the loss is: 0.054332662373781204
# Epoch 0 and the loss is: 0.24447545409202576
# Epoch 0 and the loss is: 0.07097919285297394
# Epoch 0 and the loss is: 0.059477198868989944
# Epoch 0 and the loss is: 0.09398722648620605
# Epoch 0 and the loss is: 0.08162178844213486
# Epoch 0 and the loss is: 0.06765870004892349
# Epoch 0 and the loss is: 0.11286558955907822
# Epoch 0 and the loss is: 0.2128143608570099
# Epoch 0 and the loss is: 0.14258116483688354
# Epoch 0 and the loss is: 0.0733807235956192
# Epoch 0 and the loss is: 0.087906613945961
# Epoch 0 and the loss is: 0.12270830571651459
# Epoch 0 and the loss is: 0.09931930899620056
# Epoch 0 and the loss is: 0.08662237226963043
# Epoch 0 and the loss is: 0.03385705128312111
# Epoch 0 and the loss is: 0.048229947686195374
# Epoch 0 and the loss is: 0.17656953632831573
# Epoch 0 and the loss is: 0.21780920028686523
# Epoch 0 and the loss is: 0.33003389835357666
# Epoch 0 and the loss is: 0.12136407196521759
# Epoch 0 and the loss is: 0.13977763056755066
# Epoch 0 and the loss is: 0.08436120301485062
# Epoch 0 and the loss is: 0.10994721949100494
# Epoch 0 and the loss is: 0.15618857741355896
# Epoch 0 and the loss is: 0.19229644536972046
# Epoch 0 and the loss is: 0.31317654252052307
# Epoch 0 and the loss is: 0.14415349066257477
# Epoch 0 and the loss is: 0.08323586732149124
# Epoch 0 and the loss is: 0.07687261700630188
# Epoch 0 and the loss is: 0.03979983925819397
# Epoch 0 and the loss is: 0.18547417223453522
# Epoch 0 and the loss is: 0.16935598850250244
# Epoch 0 and the loss is: 0.15588101744651794
# Epoch 0 and the loss is: 0.0619586780667305
# Epoch 0 and the loss is: 0.06488251686096191
# Epoch 0 and the loss is: 0.04856470227241516
# Epoch 0 and the loss is: 0.20536291599273682
# Epoch 0 and the loss is: 0.18041372299194336
# Epoch 0 and the loss is: 0.07888907194137573
# Epoch 0 and the loss is: 0.20924445986747742
# Epoch 0 and the loss is: 0.44678357243537903
# Epoch 0 and the loss is: 0.014447961933910847
# Epoch 0 and the loss is: 0.32744118571281433
# Epoch 0 and the loss is: 0.09618964791297913
# Epoch 0 and the loss is: 0.09004538506269455
# Epoch 0 and the loss is: 0.022601725533604622
# Epoch 0 and the loss is: 0.08494289219379425
# Epoch 0 and the loss is: 0.12375475466251373
# Epoch 0 and the loss is: 0.2819812297821045
# Epoch 0 and the loss is: 0.056369829922914505
# Epoch 0 and the loss is: 0.05415206030011177
# Epoch 0 and the loss is: 0.15954044461250305
# Epoch 0 and the loss is: 0.23698489367961884
# Epoch 0 and the loss is: 0.18388473987579346
# Epoch 0 and the loss is: 0.07420263439416885
# Epoch 0 and the loss is: 0.1595194786787033
# Epoch 0 and the loss is: 0.18329602479934692
# Epoch 0 and the loss is: 0.07185813784599304
# Epoch 0 and the loss is: 0.24732866883277893
# Epoch 0 and the loss is: 0.11583749949932098
# Epoch 0 and the loss is: 0.11743295192718506
# Epoch 0 and the loss is: 0.14907234907150269
# Epoch 0 and the loss is: 0.17265169322490692
# Epoch 0 and the loss is: 0.1388862133026123
# Epoch 0 and the loss is: 0.06426102668046951
# Epoch 0 and the loss is: 0.10592227429151535
# Epoch 0 and the loss is: 0.03329065442085266
# Epoch 0 and the loss is: 0.09299922734498978
# Epoch 0 and the loss is: 0.15954583883285522
# Epoch 0 and the loss is: 0.09609220176935196
# Epoch 0 and the loss is: 0.08580309897661209
# Epoch 0 and the loss is: 0.09495463967323303
# Epoch 0 and the loss is: 0.13049499690532684
# Epoch 0 and the loss is: 0.15757283568382263
# Epoch 0 and the loss is: 0.3151814341545105
# Epoch 0 and the loss is: 0.11824040859937668
# Epoch 0 and the loss is: 0.0763106569647789
# Epoch 0 and the loss is: 0.32801851630210876
# Epoch 0 and the loss is: 0.08316364884376526
# Epoch 0 and the loss is: 0.07203160971403122
# Epoch 0 and the loss is: 0.2272331863641739
# Epoch 0 and the loss is: 0.08739222586154938
# Epoch 0 and the loss is: 0.18026171624660492
# Epoch 0 and the loss is: 0.06652608513832092
# Epoch 0 and the loss is: 0.185221865773201
# Epoch 0 and the loss is: 0.059436358511447906
# Epoch 0 and the loss is: 0.09831711649894714
# Epoch 0 and the loss is: 0.03803228959441185
# Epoch 0 and the loss is: 0.11716074496507645
# Epoch 0 and the loss is: 0.17779766023159027
# Epoch 0 and the loss is: 0.05879024416208267
# Epoch 0 and the loss is: 0.39138874411582947
# Epoch 0 and the loss is: 0.24324126541614532
# Epoch 0 and the loss is: 0.04561559110879898
# Epoch 0 and the loss is: 0.22157390415668488
# Epoch 0 and the loss is: 0.12009353190660477
# Epoch 0 and the loss is: 0.023272043094038963
# Epoch 0 and the loss is: 0.20805414021015167
# Epoch 0 and the loss is: 0.3480260372161865
# Epoch 0 and the loss is: 0.029888782650232315
# Epoch 0 and the loss is: 0.11061619967222214
# Epoch 0 and the loss is: 0.33085280656814575
# Epoch 0 and the loss is: 0.09186091274023056
# Epoch 0 and the loss is: 0.08616646379232407
# Epoch 0 and the loss is: 0.13655458390712738
# Epoch 0 and the loss is: 0.011374179273843765
# Epoch 0 and the loss is: 0.11767027527093887
# Epoch 0 and the loss is: 0.09560983628034592
# Epoch 0 and the loss is: 0.111774742603302
# Epoch 0 and the loss is: 0.1944073885679245
# Epoch 0 and the loss is: 0.2643805742263794
# Epoch 0 and the loss is: 0.15813300013542175
# Epoch 0 and the loss is: 0.0950557291507721
# Epoch 0 and the loss is: 0.32286787033081055
# Epoch 0 and the loss is: 0.11662028729915619
# Epoch 0 and the loss is: 0.2406868040561676
# Epoch 0 and the loss is: 0.1435384750366211
# Epoch 0 and the loss is: 0.0952536016702652
# Epoch 0 and the loss is: 0.06748516112565994
# Epoch 0 and the loss is: 0.14331388473510742
# Epoch 0 and the loss is: 0.15036143362522125
# Epoch 0 and the loss is: 0.13125690817832947
# Epoch 0 and the loss is: 0.08745794743299484
# Epoch 0 and the loss is: 0.039010968059301376
# Epoch 0 and the loss is: 0.10099542886018753
# Epoch 0 and the loss is: 0.18233279883861542
# Epoch 0 and the loss is: 0.49448370933532715
# Epoch 0 and the loss is: 0.08652351796627045
# Epoch 0 and the loss is: 0.17055943608283997
# Epoch 0 and the loss is: 0.06764186918735504
# Epoch 0 and the loss is: 0.03165769204497337
# Epoch 0 and the loss is: 0.16069041192531586
# Epoch 0 and the loss is: 0.3326892852783203
# Epoch 0 and the loss is: 0.21634188294410706
# Epoch 0 and the loss is: 0.06939014792442322
# Epoch 0 and the loss is: 0.11843137443065643
# Epoch 0 and the loss is: 0.11815818399190903
# Epoch 0 and the loss is: 0.13904313743114471
# Epoch 0 and the loss is: 0.06482036411762238
# Epoch 0 and the loss is: 0.18467915058135986
# Epoch 0 and the loss is: 0.40615007281303406
# Epoch 0 and the loss is: 0.14034679532051086
# Epoch 0 and the loss is: 0.1509687900543213
# Epoch 0 and the loss is: 0.0621519573032856
# Epoch 0 and the loss is: 0.2415241301059723
# Epoch 0 and the loss is: 0.17587533593177795
# Epoch 0 and the loss is: 0.05362299084663391
# Epoch 0 and the loss is: 0.1404723972082138
# Epoch 0 and the loss is: 0.005432567093521357
# Epoch 0 and the loss is: 0.20288120210170746
# Epoch 0 and the loss is: 0.2588282525539398
# Epoch 0 and the loss is: 0.08366040885448456
# Epoch 0 and the loss is: 0.20083771646022797
# Epoch 0 and the loss is: 0.024287771433591843
# Epoch 0 and the loss is: 0.1930445283651352
# Epoch 0 and the loss is: 0.13732081651687622
# Epoch 0 and the loss is: 0.107205331325531
# Epoch 0 and the loss is: 0.03835415095090866
# Epoch 0 and the loss is: 0.16860878467559814
# Epoch 0 and the loss is: 0.17929591238498688
# Epoch 0 and the loss is: 0.42625582218170166
# Epoch 0 and the loss is: 0.11445000022649765
# Epoch 0 and the loss is: 0.16007637977600098
# Epoch 0 and the loss is: 0.054413650184869766
# Epoch 0 and the loss is: 0.22328996658325195
# Epoch 0 and the loss is: 0.22404959797859192
# Epoch 0 and the loss is: 0.19950807094573975
# Epoch 0 and the loss is: 0.05010250210762024
# Epoch 0 and the loss is: 0.01535092294216156
# Epoch 0 and the loss is: 0.049233388155698776
# Epoch 0 and the loss is: 0.04594266042113304
# Epoch 0 and the loss is: 0.07544833421707153
# Epoch 0 and the loss is: 0.19242402911186218
# Epoch 0 and the loss is: 0.11283665150403976
# Epoch 0 and the loss is: 0.0977671667933464
# Epoch 0 and the loss is: 0.12009148299694061
# Epoch 0 and the loss is: 0.18543654680252075
# Epoch 0 and the loss is: 0.1941101998090744
# Epoch 0 and the loss is: 0.01374882273375988
# Epoch 0 and the loss is: 0.034654270857572556
# Epoch 0 and the loss is: 0.06762103736400604
# Epoch 0 and the loss is: 0.16786815226078033
# Epoch 0 and the loss is: 0.021229630336165428
# Epoch 0 and the loss is: 0.310283899307251
# Epoch 0 and the loss is: 0.18058688938617706
# Epoch 0 and the loss is: 0.1524001955986023
# Epoch 0 and the loss is: 0.1371547281742096
# Epoch 0 and the loss is: 0.053939223289489746
# Epoch 0 and the loss is: 0.07415442913770676
# Epoch 0 and the loss is: 0.30521342158317566
# Epoch 0 and the loss is: 0.057795051485300064
# Epoch 0 and the loss is: 0.12191729992628098
# Epoch 0 and the loss is: 0.26705917716026306
# Epoch 0 and the loss is: 0.14337149262428284
# Epoch 0 and the loss is: 0.35931944847106934
# Epoch 0 and the loss is: 0.18617922067642212
# Epoch 0 and the loss is: 0.1563163548707962
# Epoch 0 and the loss is: 0.12877406179904938
# Epoch 0 and the loss is: 0.21891306340694427
# Epoch 0 and the loss is: 0.04354079067707062
# Epoch 0 and the loss is: 0.16332346200942993
# Epoch 0 and the loss is: 0.21664071083068848
# Epoch 0 and the loss is: 0.1061234176158905
# Epoch 0 and the loss is: 0.030968865379691124
# Epoch 0 and the loss is: 0.18056371808052063
# Epoch 0 and the loss is: 0.046620093286037445
# Epoch 0 and the loss is: 0.10707256942987442
# Epoch 0 and the loss is: 0.11920445412397385
# Epoch 0 and the loss is: 0.17928731441497803
# Epoch 0 and the loss is: 0.08552011847496033
# Epoch 0 and the loss is: 0.38165074586868286
# Epoch 0 and the loss is: 0.4169776141643524
# Epoch 0 and the loss is: 0.07401812821626663
# Epoch 0 and the loss is: 0.16614386439323425
# Epoch 0 and the loss is: 0.07152904570102692
# Epoch 0 and the loss is: 0.34071266651153564
# Epoch 0 and the loss is: 0.028415918350219727
# Epoch 0 and the loss is: 0.07199905067682266
# Epoch 0 and the loss is: 0.19223229587078094
# Epoch 0 and the loss is: 0.23761004209518433
# Epoch 0 and the loss is: 0.21027609705924988
# Epoch 0 and the loss is: 0.15163396298885345
# Epoch 0 and the loss is: 0.32912638783454895
# Epoch 0 and the loss is: 0.09248609095811844
# Epoch 0 and the loss is: 0.21121333539485931
# Epoch 0 and the loss is: 0.23791709542274475
# Epoch 0 and the loss is: 0.10818109661340714
# Epoch 0 and the loss is: 0.10991053283214569
# Epoch 0 and the loss is: 0.2273901253938675
# Epoch 0 and the loss is: 0.03280710056424141
# Epoch 0 and the loss is: 0.19055193662643433
# Epoch 0 and the loss is: 0.14105470478534698
# Epoch 0 and the loss is: 0.17698469758033752
# Epoch 0 and the loss is: 0.052428778260946274
# Epoch 0 and the loss is: 0.21367447078227997
# Epoch 0 and the loss is: 0.3919799327850342
# Epoch 0 and the loss is: 0.14035864174365997
# Epoch 0 and the loss is: 0.10523460805416107
# Epoch 0 and the loss is: 0.08614490926265717
# Epoch 0 and the loss is: 0.07936933636665344
# Epoch 0 and the loss is: 0.03731081634759903
# Epoch 0 and the loss is: 0.019881293177604675
# Epoch 0 and the loss is: 0.1696183979511261
# Epoch 0 and the loss is: 0.13695836067199707
# Epoch 0 and the loss is: 0.0824708640575409
# Epoch 0 and the loss is: 0.11342751234769821
# Epoch 0 and the loss is: 0.029757214710116386
# Epoch 0 and the loss is: 0.09075459092855453
# Epoch 0 and the loss is: 0.100498266518116
# Epoch 0 and the loss is: 0.11390502005815506
# Epoch 0 and the loss is: 0.19898489117622375
# Epoch 0 and the loss is: 0.060670774430036545
# Epoch 0 and the loss is: 0.08910864591598511
# Epoch 0 and the loss is: 0.1285376250743866
# Epoch 0 and the loss is: 0.04802713915705681
# Epoch 0 and the loss is: 0.23489868640899658
# Epoch 0 and the loss is: 0.09554878622293472
# Epoch 0 and the loss is: 0.1821388304233551
# Epoch 0 and the loss is: 0.10302897542715073
# Epoch 0 and the loss is: 0.11844751238822937
# Epoch 0 and the loss is: 0.05376759544014931
# Epoch 0 and the loss is: 0.14615854620933533
# Epoch 0 and the loss is: 0.1779407113790512
# Epoch 0 and the loss is: 0.11749109625816345
# Epoch 0 and the loss is: 0.08921948820352554
# Epoch 0 and the loss is: 0.03787444159388542
# Epoch 0 and the loss is: 0.18952526152133942
# Epoch 0 and the loss is: 0.24887657165527344
# Epoch 0 and the loss is: 0.2410293072462082
# Epoch 0 and the loss is: 0.09063434600830078
# Epoch 0 and the loss is: 0.11381158977746964
# Epoch 0 and the loss is: 0.1315830945968628
# Epoch 0 and the loss is: 0.153538316488266
# Epoch 0 and the loss is: 0.1287262886762619
# Epoch 0 and the loss is: 0.07541372627019882
# Epoch 0 and the loss is: 0.1983000636100769
# Epoch 0 and the loss is: 0.041441481560468674
# Epoch 0 and the loss is: 0.034437406808137894
# Epoch 0 and the loss is: 0.16228961944580078
# Epoch 0 and the loss is: 0.08002543449401855
# Epoch 0 and the loss is: 0.0755310133099556
# Epoch 0 and the loss is: 0.16425052285194397
# Epoch 0 and the loss is: 0.2582104802131653
# Epoch 0 and the loss is: 0.050397779792547226
# Epoch 0 and the loss is: 0.18099209666252136
# Epoch 0 and the loss is: 0.07912623137235641
# Epoch 0 and the loss is: 0.1033036932349205
# Epoch 0 and the loss is: 0.06304766982793808
# Epoch 0 and the loss is: 0.05725952982902527
# Epoch 0 and the loss is: 0.18277257680892944
# Epoch 0 and the loss is: 0.12696197628974915
# Epoch 0 and the loss is: 0.18762126564979553
# Epoch 0 and the loss is: 0.0717337504029274
# Epoch 0 and the loss is: 0.08209110796451569
# Epoch 0 and the loss is: 0.0976468101143837
# Epoch 0 and the loss is: 0.10612719506025314
# Epoch 0 and the loss is: 0.16643351316452026
# Epoch 0 and the loss is: 0.23011039197444916
# Epoch 0 and the loss is: 0.21723756194114685
# Epoch 0 and the loss is: 0.1741165816783905
# Epoch 0 and the loss is: 0.11731962114572525
# Epoch 0 and the loss is: 0.17717185616493225
# Epoch 0 and the loss is: 0.08338917791843414
# Epoch 0 and the loss is: 0.11792626976966858
# Epoch 0 and the loss is: 0.0816090852022171
# Epoch 0 and the loss is: 0.12198423594236374
# Epoch 0 and the loss is: 0.18541842699050903
# Epoch 0 and the loss is: 0.17448529601097107
# Epoch 0 and the loss is: 0.0576053261756897
# Epoch 0 and the loss is: 0.13805438578128815
# Epoch 0 and the loss is: 0.15004253387451172
# Epoch 0 and the loss is: 0.14594058692455292
# Epoch 0 and the loss is: 0.0812113955616951
# Epoch 0 and the loss is: 0.24828165769577026
# Epoch 0 and the loss is: 0.019336281344294548
# Epoch 0 and the loss is: 0.1189097911119461
# Epoch 0 and the loss is: 0.04805098474025726
# Epoch 0 and the loss is: 0.07875935733318329
# Epoch 0 and the loss is: 0.06304551661014557
# Epoch 0 and the loss is: 0.12645387649536133
# Epoch 0 and the loss is: 0.2992839813232422
# Epoch 0 and the loss is: 0.11135619878768921
# Epoch 0 and the loss is: 0.11198681592941284
# Epoch 0 and the loss is: 0.16639938950538635
# Epoch 0 and the loss is: 0.0650675892829895
# Epoch 0 and the loss is: 0.15827453136444092
# Epoch 0 and the loss is: 0.13162972033023834
# Epoch 0 and the loss is: 0.05519361421465874
# Epoch 0 and the loss is: 0.1590796262025833
# Epoch 0 and the loss is: 0.09208378195762634
# Epoch 0 and the loss is: 0.24473601579666138
# Epoch 0 and the loss is: 0.0921248123049736
# Epoch 0 and the loss is: 0.16281867027282715
# Epoch 0 and the loss is: 0.2102847844362259
# Epoch 0 and the loss is: 0.04282274842262268
# Epoch 0 and the loss is: 0.31642815470695496
# Epoch 0 and the loss is: 0.145389586687088
# Epoch 0 and the loss is: 0.11814368516206741
# Epoch 0 and the loss is: 0.16261914372444153
# Epoch 0 and the loss is: 0.04452604427933693
# Epoch 0 and the loss is: 0.3720875084400177
# Epoch 0 and the loss is: 0.15738914906978607
# Epoch 0 and the loss is: 0.07202669978141785
# Epoch 0 and the loss is: 0.11621640622615814
# Epoch 0 and the loss is: 0.21291835606098175
# Epoch 0 and the loss is: 0.10069621354341507
# Epoch 0 and the loss is: 0.1287432163953781
# Epoch 0 and the loss is: 0.5490115880966187
# Epoch 0 and the loss is: 0.10199792683124542
# Epoch 0 and the loss is: 0.13029654324054718
# Epoch 0 and the loss is: 0.17520935833454132
# Epoch 0 and the loss is: 0.33658286929130554
# Epoch 0 and the loss is: 0.034957971423864365
# Epoch 0 and the loss is: 0.05962222069501877
# Epoch 0 and the loss is: 0.03674139827489853
# Epoch 0 and the loss is: 0.08268222212791443
# Epoch 0 and the loss is: 0.12945084273815155
# Epoch 0 and the loss is: 0.14478445053100586
# Epoch 0 and the loss is: 0.30313894152641296
# Epoch 0 and the loss is: 0.33468544483184814
# Epoch 0 and the loss is: 0.395298570394516
# Epoch 0 and the loss is: 0.2404078245162964
# Epoch 0 and the loss is: 0.29237034916877747
# Epoch 0 and the loss is: 0.0662197396159172
# Epoch 0 and the loss is: 0.0713578537106514
# Epoch 0 and the loss is: 0.11867932230234146
# Epoch 0 and the loss is: 0.08731888979673386
# Epoch 0 and the loss is: 0.13033577799797058
# Epoch 0 and the loss is: 0.08161051571369171
# Epoch 0 and the loss is: 0.07575317472219467
# Epoch 0 and the loss is: 0.280206561088562
# Epoch 0 and the loss is: 0.2097586691379547
# Epoch 0 and the loss is: 0.10427963733673096
# Epoch 0 and the loss is: 0.0926007404923439
# Epoch 0 and the loss is: 0.2476474493741989
# Epoch 0 and the loss is: 0.13697455823421478
# Epoch 0 and the loss is: 0.05055635794997215
# Epoch 0 and the loss is: 0.35942351818084717
# Epoch 0 and the loss is: 0.1595848947763443
# Epoch 0 and the loss is: 0.0947529524564743
# Epoch 0 and the loss is: 0.05467460677027702
# Epoch 0 and the loss is: 0.07235785573720932
# Epoch 0 and the loss is: 0.07922118157148361
# Epoch 0 and the loss is: 0.16499744355678558
# Epoch 0 and the loss is: 0.1483992040157318
# Epoch 0 and the loss is: 0.22566543519496918
# Epoch 0 and the loss is: 0.030016576871275902
# Epoch 0 and the loss is: 0.20442131161689758
# Epoch 0 and the loss is: 0.11658909171819687
# Epoch 0 and the loss is: 0.15100449323654175
# Epoch 0 and the loss is: 0.08812389522790909
# Epoch 0 and the loss is: 0.12781278789043427
# Epoch 0 and the loss is: 0.13329951465129852
# Epoch 0 and the loss is: 0.3371557295322418
# Epoch 0 and the loss is: 0.39335399866104126
# Epoch 0 and the loss is: 0.05719900503754616
# Epoch 0 and the loss is: 0.11615288257598877
# Epoch 0 and the loss is: 0.19242508709430695
# Epoch 0 and the loss is: 0.12131031602621078
# Epoch 0 and the loss is: 0.21243509650230408
# Epoch 0 and the loss is: 0.06359926611185074
# Epoch 0 and the loss is: 0.31306421756744385
# Epoch 0 and the loss is: 0.1401015967130661
# Epoch 0 and the loss is: 0.24893797934055328
# Epoch 0 and the loss is: 0.0696726143360138
# Epoch 0 and the loss is: 0.5501774549484253
# Epoch 0 and the loss is: 0.3232434093952179
# Epoch 0 and the loss is: 0.14168494939804077
# Epoch 0 and the loss is: 0.05595267564058304
# Epoch 0 and the loss is: 0.1257432997226715
# Epoch 0 and the loss is: 0.19385139644145966
# Epoch 0 and the loss is: 0.06381291151046753
# Epoch 0 and the loss is: 0.1436261385679245
# Epoch 0 and the loss is: 0.11291994154453278
# Epoch 0 and the loss is: 0.054244816303253174
# Epoch 0 and the loss is: 0.17272841930389404
# Epoch 0 and the loss is: 0.16364546120166779
# Epoch 0 and the loss is: 0.17707544565200806
# Epoch 0 and the loss is: 0.25781354308128357
# Epoch 0 and the loss is: 0.10434052348136902
# Epoch 0 and the loss is: 0.07303213328123093
# Epoch 0 and the loss is: 0.12991759181022644
# Epoch 0 and the loss is: 0.21908196806907654
# Epoch 0 and the loss is: 0.08514024317264557
# Epoch 0 and the loss is: 0.10705140978097916
# Epoch 0 and the loss is: 0.026657290756702423
# Epoch 0 and the loss is: 0.07771582156419754
# Epoch 0 and the loss is: 0.09916979819536209
# Epoch 0 and the loss is: 0.1011003851890564
# Epoch 0 and the loss is: 0.24033762514591217
# Epoch 0 and the loss is: 0.10723554342985153
# Epoch 0 and the loss is: 0.0570070706307888
# Epoch 0 and the loss is: 0.11110217124223709
# Epoch 0 and the loss is: 0.07314660400152206
# Epoch 0 and the loss is: 0.12778210639953613
# Epoch 0 and the loss is: 0.08117638528347015
# Epoch 0 and the loss is: 0.16962385177612305
# Epoch 0 and the loss is: 0.1675649881362915
# Epoch 0 and the loss is: 0.14547012746334076
# Epoch 0 and the loss is: 0.07003894448280334
# Epoch 0 and the loss is: 0.07622011750936508
# Epoch 0 and the loss is: 0.11047203093767166
# Epoch 0 and the loss is: 0.13378533720970154
# Epoch 0 and the loss is: 0.06532272696495056
# Epoch 0 and the loss is: 0.11143450438976288
# Epoch 0 and the loss is: 0.10259784013032913
# Epoch 0 and the loss is: 0.11972173303365707
# Epoch 0 and the loss is: 0.037433113902807236
# Epoch 0 and the loss is: 0.09392289817333221
# Epoch 0 and the loss is: 0.14911247789859772
# Epoch 0 and the loss is: 0.0670645534992218
# Epoch 0 and the loss is: 0.2496354728937149
# Epoch 0 and the loss is: 0.2905968129634857
# Epoch 0 and the loss is: 0.09967473149299622
# Epoch 0 and the loss is: 0.13177885115146637
# Epoch 0 and the loss is: 0.038390059024095535
# Epoch 0 and the loss is: 0.23177246749401093
# Epoch 0 and the loss is: 0.10598738491535187
# Epoch 0 and the loss is: 0.2450198382139206
# Epoch 0 and the loss is: 0.044343095272779465
# Epoch 0 and the loss is: 0.04566703736782074
# Epoch 0 and the loss is: 0.23201234638690948
# Epoch 0 and the loss is: 0.17095117270946503
# Epoch 0 and the loss is: 0.1441933810710907
# Epoch 0 and the loss is: 0.06922125071287155
# Epoch 0 and the loss is: 0.14504756033420563
# Epoch 0 and the loss is: 0.09919750690460205
# Epoch 0 and the loss is: 0.12214922159910202
# Epoch 0 and the loss is: 0.08851626515388489
# Epoch 0 and the loss is: 0.307152658700943
# Epoch 0 and the loss is: 0.096887968480587
# Epoch 0 and the loss is: 0.07848868519067764
# Epoch 0 and the loss is: 0.1073184534907341
# Epoch 0 and the loss is: 0.05283220484852791
# Epoch 0 and the loss is: 0.13221526145935059
# Epoch 0 and the loss is: 0.09085822105407715
# Epoch 0 and the loss is: 0.037265345454216
# Epoch 0 and the loss is: 0.1076955646276474
# Epoch 0 and the loss is: 0.17635184526443481
# Epoch 0 and the loss is: 0.11759380996227264
# Epoch 0 and the loss is: 0.30120691657066345
# Epoch 0 and the loss is: 0.04601056128740311
# Epoch 0 and the loss is: 0.08227323740720749
# Epoch 0 and the loss is: 0.1202460378408432
# Epoch 0 and the loss is: 0.08094285428524017
# Epoch 0 and the loss is: 0.21637220680713654
# Epoch 0 and the loss is: 0.20884525775909424
# Epoch 0 and the loss is: 0.025247380137443542
# Epoch 0 and the loss is: 0.047243449836969376
# Epoch 0 and the loss is: 0.31990450620651245
# Epoch 0 and the loss is: 0.02743096649646759
# Epoch 0 and the loss is: 0.06563495099544525
# Epoch 0 and the loss is: 0.11675888299942017
# Epoch 0 and the loss is: 0.2712445855140686
# Epoch 0 and the loss is: 0.18054834008216858
# Epoch 0 and the loss is: 0.21828195452690125
# Epoch 0 and the loss is: 0.1743374913930893
# Epoch 0 and the loss is: 0.07402121275663376
# Epoch 0 and the loss is: 0.09071024507284164
# Epoch 0 and the loss is: 0.2786921262741089
# Epoch 0 and the loss is: 0.0805947482585907
# Epoch 0 and the loss is: 0.09794717282056808
# Epoch 0 and the loss is: 0.12553079426288605
# Epoch 0 and the loss is: 0.1613726019859314
# Epoch 0 and the loss is: 0.08323996514081955
# Epoch 0 and the loss is: 0.2598831057548523
# Epoch 0 and the loss is: 0.02924443781375885
# Epoch 0 and the loss is: 0.1202901229262352
# Epoch 0 and the loss is: 0.10635925084352493
# Epoch 0 and the loss is: 0.12126696854829788
# Epoch 0 and the loss is: 0.2510955035686493
# Epoch 0 and the loss is: 0.14405733346939087
# Epoch 0 and the loss is: 0.08459436148405075
# Epoch 0 and the loss is: 0.30782461166381836
# Epoch 0 and the loss is: 0.06962189823389053
# Epoch 0 and the loss is: 0.07557152211666107
# Epoch 0 and the loss is: 0.2860087454319
# Epoch 0 and the loss is: 0.04905780032277107
# Epoch 0 and the loss is: 0.12969523668289185
# Epoch 0 and the loss is: 0.14782752096652985
# Epoch 0 and the loss is: 0.12142504006624222
# Epoch 0 and the loss is: 0.25433507561683655
# Epoch 0 and the loss is: 0.053086504340171814
# Epoch 0 and the loss is: 0.1470300406217575
# Epoch 0 and the loss is: 0.153835266828537
# Epoch 0 and the loss is: 0.07745950669050217
# Epoch 0 and the loss is: 0.08654230833053589
# Epoch 0 and the loss is: 0.169619619846344
# Epoch 0 and the loss is: 0.12893007695674896
# Epoch 0 and the loss is: 0.1401103287935257
# Epoch 0 and the loss is: 0.12553651630878448
# Epoch 0 and the loss is: 0.1160651296377182
# Epoch 0 and the loss is: 0.11731579154729843
# Epoch 0 and the loss is: 0.1398313343524933
# Epoch 0 and the loss is: 0.1555272936820984
# Epoch 0 and the loss is: 0.02876848541200161
# Epoch 0 and the loss is: 0.09422130137681961
# Epoch 0 and the loss is: 0.060640476644039154
# Epoch 0 and the loss is: 0.18216374516487122
# Epoch 0 and the loss is: 0.2537919878959656
# Epoch 0 and the loss is: 0.1772569715976715
# Epoch 0 and the loss is: 0.029308028519153595
# Epoch 0 and the loss is: 0.09080258011817932
# Epoch 0 and the loss is: 0.24942989647388458
# Epoch 0 and the loss is: 0.14589165151119232
# Epoch 0 and the loss is: 0.14571219682693481
# Epoch 0 and the loss is: 0.17513374984264374
# Epoch 0 and the loss is: 0.291360080242157
# Epoch 0 and the loss is: 0.184219628572464
# Epoch 0 and the loss is: 0.07799772918224335
# Epoch 0 and the loss is: 0.2081030309200287
# Epoch 0 and the loss is: 0.08887099474668503
# Epoch 0 and the loss is: 0.07675975561141968
# Epoch 0 and the loss is: 0.20610930025577545
# Epoch 0 and the loss is: 0.23063090443611145
# Epoch 0 and the loss is: 0.0973924770951271
# Epoch 0 and the loss is: 0.16699260473251343
# Epoch 0 and the loss is: 0.2332868129014969
# Epoch 0 and the loss is: 0.207066148519516
# Epoch 0 and the loss is: 0.13165661692619324
# Epoch 0 and the loss is: 0.23626554012298584
# Epoch 0 and the loss is: 0.2666342556476593
# Epoch 0 and the loss is: 0.20718863606452942
# Epoch 0 and the loss is: 0.19296854734420776
# Epoch 0 and the loss is: 0.08988779783248901
# Epoch 0 and the loss is: 0.1673295944929123
# Epoch 0 and the loss is: 0.15409298241138458
# Epoch 0 and the loss is: 0.13537092506885529
# Epoch 0 and the loss is: 0.05606372654438019
# Epoch 0 and the loss is: 0.03467337042093277
# Epoch 0 and the loss is: 0.13125592470169067
# Epoch 0 and the loss is: 0.06433073431253433
# Epoch 0 and the loss is: 0.03300652280449867
# Epoch 0 and the loss is: 0.2952498495578766
# Epoch 0 and the loss is: 0.34973517060279846
# Epoch 0 and the loss is: 0.09775912016630173
# Epoch 0 and the loss is: 0.04454205185174942
# Epoch 0 and the loss is: 0.14832070469856262
# Epoch 0 and the loss is: 0.38316914439201355
# Epoch 0 and the loss is: 0.13148538768291473
# Epoch 0 and the loss is: 0.07718998938798904
# Epoch 0 and the loss is: 0.11105074733495712
# Epoch 0 and the loss is: 0.09072603285312653
# Epoch 0 and the loss is: 0.1024177297949791
# Epoch 0 and the loss is: 0.12338313460350037
# Epoch 0 and the loss is: 0.14802509546279907
# Epoch 0 and the loss is: 0.08816707879304886
# Epoch 0 and the loss is: 0.14352145791053772
# Epoch 0 and the loss is: 0.3412366509437561
# Epoch 0 and the loss is: 0.09464602172374725
# Epoch 0 and the loss is: 0.24399974942207336
# Epoch 0 and the loss is: 0.2523845434188843
# Epoch 0 and the loss is: 0.0969003215432167
# Epoch 0 and the loss is: 0.2695688307285309
# Epoch 0 and the loss is: 0.055595703423023224
# Epoch 0 and the loss is: 0.10208152234554291
# Epoch 0 and the loss is: 0.06707821041345596
# Epoch 0 and the loss is: 0.15683063864707947
# Epoch 0 and the loss is: 0.11394308507442474
# Epoch 0 and the loss is: 0.2461179941892624
# Epoch 0 and the loss is: 0.19007575511932373
# Epoch 0 and the loss is: 0.09976252913475037
# Epoch 0 and the loss is: 0.08850419521331787
# Epoch 0 and the loss is: 0.16268779337406158
# Epoch 0 and the loss is: 0.17437127232551575
# Epoch 0 and the loss is: 0.07328925281763077
# Epoch 0 and the loss is: 0.25555717945098877
# Epoch 0 and the loss is: 0.15204912424087524
# Epoch 0 and the loss is: 0.06679720431566238
# Epoch 0 and the loss is: 0.38828110694885254
# Epoch 0 and the loss is: 0.13936232030391693
# Epoch 0 and the loss is: 0.19902490079402924
# Epoch 0 and the loss is: 0.06087939441204071
# Epoch 0 and the loss is: 0.1107025146484375
# Epoch 0 and the loss is: 0.10829372704029083
# Epoch 0 and the loss is: 0.1394498199224472
# Epoch 0 and the loss is: 0.06443482637405396
# Epoch 0 and the loss is: 0.1339104175567627
# Epoch 0 and the loss is: 0.13170160353183746
# Epoch 0 and the loss is: 0.07516072690486908
# Epoch 0 and the loss is: 0.2996523976325989
# Epoch 0 and the loss is: 0.12348944693803787
# Epoch 0 and the loss is: 0.22835245728492737
# Epoch 0 and the loss is: 0.0441419892013073
# Epoch 0 and the loss is: 0.08661646395921707
# Epoch 0 and the loss is: 0.14569398760795593
# Epoch 0 and the loss is: 0.10876252502202988
# Epoch 0 and the loss is: 0.269830584526062
# Epoch 0 and the loss is: 0.29079726338386536
# Epoch 0 and the loss is: 0.06257247924804688
# Epoch 0 and the loss is: 0.11690013855695724
# Epoch 0 and the loss is: 0.13727442920207977
# Epoch 0 and the loss is: 0.13918836414813995
# Epoch 0 and the loss is: 0.05664227530360222
# Epoch 0 and the loss is: 0.05563880130648613
# Epoch 0 and the loss is: 0.10611854493618011
# Epoch 0 and the loss is: 0.1266736388206482
# Epoch 0 and the loss is: 0.146208718419075
# Epoch 0 and the loss is: 0.13607259094715118
# Epoch 0 and the loss is: 0.038322046399116516
# Epoch 0 and the loss is: 0.05886318162083626
# Epoch 0 and the loss is: 0.20688942074775696
# Epoch 0 and the loss is: 0.18747621774673462
# Epoch 0 and the loss is: 0.13227896392345428
# Epoch 0 and the loss is: 0.17030006647109985
# Epoch 0 and the loss is: 0.18298453092575073
# Epoch 0 and the loss is: 0.31286680698394775
# Epoch 0 and the loss is: 0.18009456992149353
# Epoch 0 and the loss is: 0.3361915647983551
# Epoch 0 and the loss is: 0.08728691935539246
# Epoch 0 and the loss is: 0.14949855208396912
# Epoch 0 and the loss is: 0.3613508939743042
# Epoch 0 and the loss is: 0.07932277023792267
# Epoch 0 and the loss is: 0.12825219333171844
# Epoch 0 and the loss is: 0.07224012166261673
# Epoch 0 and the loss is: 0.2368173897266388
# Epoch 0 and the loss is: 0.1984318047761917
# Epoch 0 and the loss is: 0.0806489810347557
# Epoch 0 and the loss is: 0.07478982210159302
# Epoch 0 and the loss is: 0.06326906383037567
# Epoch 0 and the loss is: 0.10793089866638184
# Epoch 0 and the loss is: 0.3925184905529022
# Epoch 0 and the loss is: 0.18607676029205322
# Epoch 0 and the loss is: 0.3538937568664551
# Epoch 0 and the loss is: 0.09147407114505768
# Epoch 0 and the loss is: 0.40242820978164673
# Epoch 0 and the loss is: 0.3085138499736786
# Epoch 0 and the loss is: 0.045343656092882156
# Epoch 0 and the loss is: 0.24049359560012817
# Epoch 0 and the loss is: 0.4891410171985626
# Epoch 0 and the loss is: 0.27838802337646484
# Epoch 0 and the loss is: 0.18984507024288177
# Epoch 0 and the loss is: 0.1375572830438614
# Epoch 0 and the loss is: 0.19663608074188232
# Epoch 0 and the loss is: 0.14666976034641266
# Epoch 0 and the loss is: 0.12963593006134033
# Epoch 0 and the loss is: 0.09652652591466904
# Epoch 0 and the loss is: 0.12534968554973602
# Epoch 0 and the loss is: 0.18361890316009521
# Epoch 0 and the loss is: 0.13477744162082672
# Epoch 0 and the loss is: 0.08334233611822128
# Epoch 0 and the loss is: 0.24694418907165527
# Epoch 0 and the loss is: 0.33464911580085754
# Epoch 0 and the loss is: 0.09329886734485626
# Epoch 0 and the loss is: 0.06324170529842377
# Epoch 0 and the loss is: 0.2706756889820099
# Epoch 0 and the loss is: 0.4446345865726471
# Epoch 0 and the loss is: 0.08041292428970337
# Epoch 0 and the loss is: 0.06942170113325119
# Epoch 0 and the loss is: 0.22956226766109467
# Epoch 0 and the loss is: 0.11458846181631088
# Epoch 0 and the loss is: 0.14065803587436676
# Epoch 0 and the loss is: 0.17690330743789673
# Epoch 0 and the loss is: 0.27752476930618286
# Epoch 0 and the loss is: 0.08872968703508377
# Epoch 0 and the loss is: 0.07505441457033157
# Epoch 0 and the loss is: 0.07759524881839752
# Epoch 0 and the loss is: 0.1260099709033966
# Epoch 0 and the loss is: 0.056901413947343826
# Epoch 0 and the loss is: 0.3433220684528351
# Epoch 0 and the loss is: 0.09819236397743225
# Epoch 0 and the loss is: 0.07195499539375305
# Epoch 0 and the loss is: 0.2439088225364685
# Epoch 0 and the loss is: 0.5514359474182129
# Epoch 0 and the loss is: 0.18802984058856964
# Epoch 0 and the loss is: 0.22597302496433258
# Epoch 0 and the loss is: 0.1144610047340393
# Epoch 0 and the loss is: 0.0909361019730568
# Epoch 0 and the loss is: 0.05476277321577072
# Epoch 0 and the loss is: 0.039746496826410294
# Epoch 0 and the loss is: 0.16360554099082947
# Epoch 0 and the loss is: 0.10341108590364456
# Epoch 0 and the loss is: 0.09984000027179718
# Epoch 0 and the loss is: 0.4287595748901367
# Epoch 0 and the loss is: 0.14087486267089844
# Epoch 0 and the loss is: 0.07871544361114502
# Epoch 0 and the loss is: 0.11561092734336853
# Epoch 0 and the loss is: 0.09137924760580063
# Epoch 0 and the loss is: 0.15586881339550018
# Epoch 0 and the loss is: 0.11314374208450317
# Epoch 0 and the loss is: 0.19452223181724548
# Epoch 0 and the loss is: 0.15622320771217346
# Epoch 0 and the loss is: 0.2495192438364029
# Epoch 0 and the loss is: 0.16029269993305206
# Epoch 0 and the loss is: 0.1060643345117569
# Epoch 0 and the loss is: 0.13731315732002258
# Epoch 0 and the loss is: 0.05477644130587578
# Epoch 0 and the loss is: 0.1632668673992157
# Epoch 0 and the loss is: 0.14309148490428925
# Epoch 0 and the loss is: 0.04113592207431793
# Epoch 0 and the loss is: 0.17376379668712616
# Epoch 0 and the loss is: 0.2282557636499405
# Epoch 0 and the loss is: 0.06188495457172394
# Epoch 0 and the loss is: 0.22709548473358154
# Epoch 0 and the loss is: 0.11919421702623367
# Epoch 0 and the loss is: 0.2706508934497833
# Epoch 0 and the loss is: 0.060550469905138016
# Epoch 0 and the loss is: 0.12778137624263763
# Epoch 0 and the loss is: 0.05048419535160065
# Epoch 0 and the loss is: 0.14998279511928558
# Epoch 0 and the loss is: 0.22948820888996124
# Epoch 0 and the loss is: 0.14378219842910767
# Epoch 0 and the loss is: 0.11624738574028015
# Epoch 0 and the loss is: 0.3421850800514221
# Epoch 0 and the loss is: 0.2533904016017914
# Epoch 0 and the loss is: 0.18434129655361176
# Epoch 0 and the loss is: 0.2983715236186981
# Epoch 0 and the loss is: 0.13306526839733124
# Epoch 0 and the loss is: 0.031614743173122406
# Epoch 0 and the loss is: 0.02823352813720703
# Epoch 0 and the loss is: 0.056770212948322296
# Epoch 0 and the loss is: 0.12599924206733704
# Epoch 0 and the loss is: 0.040571074932813644
# Epoch 0 and the loss is: 0.06550729274749756
# Epoch 0 and the loss is: 0.01696963794529438
# Epoch 0 and the loss is: 0.14847423136234283
# Epoch 0 and the loss is: 0.192377507686615
# Epoch 0 and the loss is: 0.08046767860651016
# Epoch 0 and the loss is: 0.11134445667266846
# Epoch 0 and the loss is: 0.24660134315490723
# Epoch 0 and the loss is: 0.10283702611923218
# Epoch 0 and the loss is: 0.05322752520442009
# Epoch 0 and the loss is: 0.18720702826976776
# Epoch 0 and the loss is: 0.1413578987121582
# Epoch 0 and the loss is: 0.07427418977022171
# Epoch 0 and the loss is: 0.08688342571258545
# Epoch 0 and the loss is: 0.2686741054058075
# Epoch 0 and the loss is: 0.04891052842140198
# Epoch 0 and the loss is: 0.17315778136253357
# Epoch 0 and the loss is: 0.22975461184978485
# Epoch 0 and the loss is: 0.05769747868180275
# Epoch 0 and the loss is: 0.058757420629262924
# Epoch 0 and the loss is: 0.21566364169120789
# Epoch 0 and the loss is: 0.06909436732530594
# Epoch 0 and the loss is: 0.04797236621379852
# Epoch 0 and the loss is: 0.03408364579081535
# Epoch 0 and the loss is: 0.2914617955684662
# Epoch 0 and the loss is: 0.10092238336801529
# Epoch 0 and the loss is: 0.21751970052719116
# Epoch 0 and the loss is: 0.09195538610219955
# Epoch 0 and the loss is: 0.07494406402111053
# Epoch 0 and the loss is: 0.11944914609193802
# Epoch 0 and the loss is: 0.12767063081264496
# Epoch 0 and the loss is: 0.20212632417678833
# Epoch 0 and the loss is: 0.1799822896718979
# Epoch 0 and the loss is: 0.0599726177752018
# Epoch 0 and the loss is: 0.0673224925994873
# Epoch 0 and the loss is: 0.17699606716632843
# Epoch 0 and the loss is: 0.20369739830493927
# Epoch 0 and the loss is: 0.21980315446853638
# Epoch 0 and the loss is: 0.05758785456418991
# Epoch 0 and the loss is: 0.053917527198791504
# Epoch 0 and the loss is: 0.1034315899014473
# Epoch 0 and the loss is: 0.06029146909713745
# Epoch 0 and the loss is: 0.20774413645267487
# Epoch 0 and the loss is: 0.2902951240539551
# Epoch 0 and the loss is: 0.1256234496831894
# Epoch 0 and the loss is: 0.3274354636669159
# Epoch 0 and the loss is: 0.15174740552902222
# Epoch 0 and the loss is: 0.04433843493461609
# Epoch 0 and the loss is: 0.21438980102539062
# Epoch 0 and the loss is: 0.2629145383834839
# Epoch 0 and the loss is: 0.2645430564880371
# Epoch 0 and the loss is: 0.27234119176864624
# Epoch 0 and the loss is: 0.17251336574554443
# Epoch 0 and the loss is: 0.07681276649236679
# Epoch 0 and the loss is: 0.024665210396051407
# Epoch 0 and the loss is: 0.2405599057674408
# Epoch 0 and the loss is: 0.24665279686450958
# Epoch 0 and the loss is: 0.10078202188014984
# Epoch 0 and the loss is: 0.16549021005630493
# Epoch 0 and the loss is: 0.20225611329078674
# Epoch 0 and the loss is: 0.08378888666629791
# Epoch 0 and the loss is: 0.19230523705482483
# Epoch 0 and the loss is: 0.3560142517089844
# Epoch 0 and the loss is: 0.19765031337738037
# Epoch 0 and the loss is: 0.23068010807037354
# Epoch 0 and the loss is: 0.23256811499595642
# Epoch 0 and the loss is: 0.019828395918011665
# Epoch 0 and the loss is: 0.0769021138548851
# Epoch 0 and the loss is: 0.21737487614154816
# Epoch 0 and the loss is: 0.1309247463941574
# Epoch 0 and the loss is: 0.10639985650777817
# Epoch 0 and the loss is: 0.4257374703884125
# Epoch 0 and the loss is: 0.10737603902816772
# Epoch 0 and the loss is: 0.25295424461364746
# Epoch 0 and the loss is: 0.17192977666854858
# Epoch 0 and the loss is: 0.09212800860404968
# Epoch 0 and the loss is: 0.11851143091917038
# Epoch 0 and the loss is: 0.19885125756263733
# Epoch 0 and the loss is: 0.08084148913621902
# Epoch 0 and the loss is: 0.06119302287697792
# Epoch 0 and the loss is: 0.12000053375959396
# Epoch 0 and the loss is: 0.2695215344429016
# Epoch 0 and the loss is: 0.10926971584558487
# Epoch 0 and the loss is: 0.12083494663238525
# Epoch 0 and the loss is: 0.20196516811847687
# Epoch 0 and the loss is: 0.04416026920080185
# Epoch 0 and the loss is: 0.20049993693828583
# Epoch 0 and the loss is: 0.12737080454826355
# Epoch 0 and the loss is: 0.1705184131860733
# Epoch 0 and the loss is: 0.3346989154815674
# Epoch 0 and the loss is: 0.22043846547603607
# Epoch 0 and the loss is: 0.13121771812438965
# Epoch 0 and the loss is: 0.14083197712898254
# Epoch 0 and the loss is: 0.02126353792846203
# Epoch 0 and the loss is: 0.13598403334617615
# Epoch 0 and the loss is: 0.0452633798122406
# Epoch 0 and the loss is: 0.1824714094400406
# Epoch 0 and the loss is: 0.11657264828681946
# Epoch 0 and the loss is: 0.15856565535068512
# Epoch 0 and the loss is: 0.08590276539325714
# Epoch 0 and the loss is: 0.07006388902664185
# Epoch 0 and the loss is: 0.14735589921474457
# Epoch 0 and the loss is: 0.06760666519403458
# Epoch 0 and the loss is: 0.07952447980642319
# Epoch 0 and the loss is: 0.1149674654006958
# Epoch 0 and the loss is: 0.11621274054050446
# Epoch 0 and the loss is: 0.164473295211792
# Epoch 0 and the loss is: 0.1503356397151947
# Epoch 0 and the loss is: 0.13692989945411682
# Epoch 0 and the loss is: 0.12340248376131058
# Epoch 0 and the loss is: 0.10338880121707916
# Epoch 0 and the loss is: 0.15170767903327942
# Epoch 0 and the loss is: 0.09056870639324188
# Epoch 0 and the loss is: 0.05944814532995224
# Epoch 0 and the loss is: 0.222957581281662
# Epoch 0 and the loss is: 0.0492754764854908
# Epoch 0 and the loss is: 0.08234993368387222
# Epoch 0 and the loss is: 0.2484683096408844
# Epoch 0 and the loss is: 0.15017575025558472
# Epoch 0 and the loss is: 0.16018474102020264
# Epoch 0 and the loss is: 0.10798541456460953
# Epoch 0 and the loss is: 0.03229232504963875
# Epoch 0 and the loss is: 0.28594207763671875
# Epoch 0 and the loss is: 0.07542041689157486
# Epoch 0 and the loss is: 0.16636976599693298
# Epoch 0 and the loss is: 0.1416306048631668
# Epoch 0 and the loss is: 0.3069654107093811
# Epoch 0 and the loss is: 0.14539869129657745
# Epoch 0 and the loss is: 0.05260107293725014
# Epoch 0 and the loss is: 0.11853114515542984
# Epoch 0 and the loss is: 0.12390930205583572
# Epoch 0 and the loss is: 0.1274031400680542
# Epoch 0 and the loss is: 0.1947236955165863
# Epoch 0 and the loss is: 0.03289605677127838
# Epoch 0 and the loss is: 0.20903116464614868
# Epoch 0 and the loss is: 0.2971343696117401
# Epoch 0 and the loss is: 0.14830835163593292
# Epoch 0 and the loss is: 0.1552646905183792
# Epoch 0 and the loss is: 0.11838407814502716
# Epoch 0 and the loss is: 0.07041558623313904
# Epoch 0 and the loss is: 0.19243690371513367
# Epoch 0 and the loss is: 0.046250563114881516
# Epoch 0 and the loss is: 0.158213272690773
# Epoch 0 and the loss is: 0.40996405482292175
# Epoch 0 and the loss is: 0.19983139634132385
# Epoch 0 and the loss is: 0.21699278056621552
# Epoch 0 and the loss is: 0.06080228090286255
# Epoch 0 and the loss is: 0.09239815175533295
# Epoch 0 and the loss is: 0.27475833892822266
# Epoch 0 and the loss is: 0.030047068372368813
# Epoch 0 and the loss is: 0.2510049045085907
# Epoch 0 and the loss is: 0.38256600499153137
# Epoch 0 and the loss is: 0.04821508750319481
# Epoch 0 and the loss is: 0.15195739269256592
# Epoch 0 and the loss is: 0.5197036266326904
# Epoch 0 and the loss is: 0.0813964307308197
# Epoch 0 and the loss is: 0.2919328510761261
# Epoch 0 and the loss is: 0.04795895144343376
# Epoch 0 and the loss is: 0.06963714212179184
# Epoch 0 and the loss is: 0.040400754660367966
# Epoch 0 and the loss is: 0.18124467134475708
# Epoch 0 and the loss is: 0.0821235254406929
# Epoch 0 and the loss is: 0.17014530301094055
# Epoch 0 and the loss is: 0.11870283633470535
# Epoch 0 and the loss is: 0.0870441347360611
# Epoch 0 and the loss is: 0.11496079713106155
# Epoch 0 and the loss is: 0.04422708600759506
# Epoch 0 and the loss is: 0.028605632483959198
# Epoch 0 and the loss is: 0.13218927383422852
# Epoch 0 and the loss is: 0.08401624858379364
# Epoch 0 and the loss is: 0.11472002416849136
# Epoch 0 and the loss is: 0.10904116183519363
# Epoch 0 and the loss is: 0.10014510899782181
# Epoch 0 and the loss is: 0.14946706593036652
# Epoch 0 and the loss is: 0.0477263517677784
# Epoch 0 and the loss is: 0.48239201307296753
# Epoch 0 and the loss is: 0.2613503634929657
# Epoch 0 and the loss is: 0.11175882816314697
# Epoch 0 and the loss is: 0.1508893221616745
# Epoch 0 and the loss is: 0.03971432149410248
# Epoch 0 and the loss is: 0.09830533713102341
# Epoch 0 and the loss is: 0.020877258852124214
# Epoch 0 and the loss is: 0.181602343916893
# Epoch 0 and the loss is: 0.07275164127349854
# Epoch 0 and the loss is: 0.03048565983772278
# Epoch 0 and the loss is: 0.08463317900896072
# Epoch 0 and the loss is: 0.26706573367118835
# Epoch 0 and the loss is: 0.041097141802310944
# Epoch 0 and the loss is: 0.10946636646986008
# Epoch 0 and the loss is: 0.09312054514884949
# Epoch 0 and the loss is: 0.2507891356945038
# Epoch 0 and the loss is: 0.24024465680122375
# Epoch 0 and the loss is: 0.05390981584787369
# Epoch 0 and the loss is: 0.1225179061293602
# Epoch 0 and the loss is: 0.14039663970470428
# Epoch 0 and the loss is: 0.3076063394546509
# Epoch 0 and the loss is: 0.02931641973555088
# Epoch 0 and the loss is: 0.0977238267660141
# Epoch 0 and the loss is: 0.07820171862840652
# Epoch 0 and the loss is: 0.22820092737674713
# Epoch 0 and the loss is: 0.1328536868095398
# Epoch 0 and the loss is: 0.05391724035143852
# Epoch 0 and the loss is: 0.015766583383083344
# Epoch 0 and the loss is: 0.042417239397764206
# Epoch 0 and the loss is: 0.26515552401542664
# Epoch 0 and the loss is: 0.33175402879714966
# Epoch 0 and the loss is: 0.28944748640060425
# Epoch 0 and the loss is: 0.28354549407958984
# Epoch 0 and the loss is: 0.2317029982805252
# Epoch 0 and the loss is: 0.26871782541275024
# Epoch 0 and the loss is: 0.20244599878787994
# Epoch 0 and the loss is: 0.10654633492231369
# Epoch 0 and the loss is: 0.12284859269857407
# Epoch 0 and the loss is: 0.023928014561533928
# Epoch 0 and the loss is: 0.08870409429073334
# Epoch 0 and the loss is: 0.03204254060983658
# Epoch 0 and the loss is: 0.24630703032016754
# Epoch 0 and the loss is: 0.21305017173290253
# Epoch 0 and the loss is: 0.12238522619009018
# Epoch 0 and the loss is: 0.10273351520299911
# Epoch 0 and the loss is: 0.08725747466087341
# Epoch 0 and the loss is: 0.14655517041683197
# Epoch 0 and the loss is: 0.09655667096376419
# Epoch 0 and the loss is: 0.24393388628959656
# Epoch 0 and the loss is: 0.36480867862701416
# Epoch 0 and the loss is: 0.41807821393013
# Epoch 0 and the loss is: 0.143980473279953
# Epoch 0 and the loss is: 0.09794558584690094
# Epoch 0 and the loss is: 0.33894988894462585
# Epoch 0 and the loss is: 0.10162454843521118
# Epoch 0 and the loss is: 0.26866093277931213
# Epoch 0 and the loss is: 0.163670152425766
# Epoch 0 and the loss is: 0.3285759687423706
# Epoch 0 and the loss is: 0.17950889468193054
# Epoch 0 and the loss is: 0.1912466138601303
# Epoch 0 and the loss is: 0.14274854958057404
# Epoch 0 and the loss is: 0.23376470804214478
# Epoch 0 and the loss is: 0.07855944335460663
# Epoch 0 and the loss is: 0.10540600121021271
# Epoch 0 and the loss is: 0.2133316695690155
# Epoch 0 and the loss is: 0.10473751276731491
# Epoch 0 and the loss is: 0.15047265589237213
# Epoch 0 and the loss is: 0.12069733440876007
# Epoch 0 and the loss is: 0.2678215801715851
# Epoch 0 and the loss is: 0.10761431604623795
# Epoch 0 and the loss is: 0.07615719735622406
# Epoch 0 and the loss is: 0.03691883012652397
# Epoch 0 and the loss is: 0.1195322647690773
# Epoch 0 and the loss is: 0.2811949551105499
# Epoch 0 and the loss is: 0.1649344265460968
# Epoch 0 and the loss is: 0.16826529800891876
# Epoch 0 and the loss is: 0.37060126662254333
# Epoch 0 and the loss is: 0.1921231746673584
# Epoch 0 and the loss is: 0.26460421085357666
# Epoch 0 and the loss is: 0.04524172097444534
# Epoch 0 and the loss is: 0.2739449739456177
# Epoch 0 and the loss is: 0.04730115830898285
# Epoch 0 and the loss is: 0.1887955367565155
# Epoch 0 and the loss is: 0.07700613141059875
# Epoch 0 and the loss is: 0.10305643081665039
# Epoch 0 and the loss is: 0.16173629462718964
# Epoch 0 and the loss is: 0.07138430327177048
# Epoch 0 and the loss is: 0.056326474994421005
# Epoch 0 and the loss is: 0.07576825469732285
# Epoch 0 and the loss is: 0.10347398370504379
# Epoch 0 and the loss is: 0.12028210610151291
# Epoch 0 and the loss is: 0.03284960612654686
# Epoch 0 and the loss is: 0.12556815147399902
# Epoch 0 and the loss is: 0.1238628402352333
# Epoch 0 and the loss is: 0.0810592845082283
# Epoch 0 and the loss is: 0.24707086384296417
# Epoch 0 and the loss is: 0.170707106590271
# Epoch 0 and the loss is: 0.23108041286468506
# Epoch 0 and the loss is: 0.062173616141080856
# Epoch 0 and the loss is: 0.038197170943021774
# Epoch 0 and the loss is: 0.10417579114437103
# Epoch 0 and the loss is: 0.1471511572599411
# Epoch 0 and the loss is: 0.2781360447406769
# Epoch 0 and the loss is: 0.10820403695106506
# Epoch 0 and the loss is: 0.1705159693956375
# Epoch 0 and the loss is: 0.4194701313972473
# Epoch 0 and the loss is: 0.16554801166057587
# Epoch 0 and the loss is: 0.2233327031135559
# Epoch 0 and the loss is: 0.05957222357392311
# Epoch 0 and the loss is: 0.13579772412776947
# Epoch 0 and the loss is: 0.09517649561166763
# ...
# Epoch 9 and the loss is: 0.03638644516468048
# Epoch 9 and the loss is: 0.19624154269695282
# Epoch 9 and the loss is: 0.013056045398116112
# Epoch 9 and the loss is: 0.12166468799114227
# Epoch 9 and the loss is: 0.0014330130070447922
# Epoch 9 and the loss is: 0.07168348133563995
# Epoch 9 and the loss is: 0.029084065929055214
# Epoch 9 and the loss is: 0.03486323356628418
# Epoch 9 and the loss is: 0.19775095582008362
# Epoch 9 and the loss is: 0.34705495834350586
# Epoch 9 and the loss is: 0.004181866999715567
# Epoch 9 and the loss is: 0.129258930683136
# Epoch 9 and the loss is: 0.08252783119678497
# Epoch 9 and the loss is: 0.07084190845489502
# Epoch 9 and the loss is: 0.007177880499511957
# Epoch 9 and the loss is: 0.09828553348779678
# Epoch 9 and the loss is: 0.07358517497777939
# Epoch 9 and the loss is: 0.061993274837732315
# Epoch 9 and the loss is: 0.008802160620689392
# Epoch 9 and the loss is: 0.2648400664329529
# Epoch 9 and the loss is: 0.13045334815979004
# Epoch 9 and the loss is: 0.2031525820493698
# Epoch 9 and the loss is: 0.032243721187114716
# Epoch 9 and the loss is: 0.237563818693161
# Epoch 9 and the loss is: 0.03628172352910042
# Epoch 9 and the loss is: 0.13666008412837982
# Epoch 9 and the loss is: 0.1171366423368454
# Epoch 9 and the loss is: 0.03333704173564911
# Epoch 9 and the loss is: 0.1587267369031906
# Epoch 9 and the loss is: 0.06193753331899643
# Epoch 9 and the loss is: 0.02800682559609413
# Epoch 9 and the loss is: 0.14830109477043152
# Epoch 9 and the loss is: 0.031462252140045166
# Epoch 9 and the loss is: 0.053009334951639175
# Epoch 9 and the loss is: 0.1147317886352539
# Epoch 9 and the loss is: 0.1366802155971527
# Epoch 9 and the loss is: 0.11493853479623795
# Epoch 9 and the loss is: 0.08166017383337021
# Epoch 9 and the loss is: 0.010939027182757854
# Epoch 9 and the loss is: 0.05792425200343132
# Epoch 9 and the loss is: 0.1131562739610672
# Epoch 9 and the loss is: 0.2024616152048111
# Epoch 9 and the loss is: 0.1267644464969635
# Epoch 9 and the loss is: 0.046831730753183365
# Epoch 9 and the loss is: 0.10963831841945648
# Epoch 9 and the loss is: 0.08231277018785477
# Epoch 9 and the loss is: 0.05873178690671921
# Epoch 9 and the loss is: 0.11271362751722336
# Epoch 9 and the loss is: 0.06919723004102707
# Epoch 9 and the loss is: 0.10788469016551971
# Epoch 9 and the loss is: 0.012062989175319672
# Epoch 9 and the loss is: 0.1886303424835205
# Epoch 9 and the loss is: 0.09926242381334305
# Epoch 9 and the loss is: 0.19413509964942932
# Epoch 9 and the loss is: 0.08606606721878052
# Epoch 9 and the loss is: 0.09346920251846313
# Epoch 9 and the loss is: 0.02454216778278351
# Epoch 9 and the loss is: 0.09296675771474838
# Epoch 9 and the loss is: 0.0797208696603775
# Epoch 9 and the loss is: 0.15589694678783417
# Epoch 9 and the loss is: 0.02527923509478569
# Epoch 9 and the loss is: 0.021534685045480728
# Epoch 9 and the loss is: 0.033362362533807755
# Epoch 9 and the loss is: 0.05799425020813942
# Epoch 9 and the loss is: 0.009167526848614216
# Epoch 9 and the loss is: 0.058936331421136856
# Epoch 9 and the loss is: 0.02111082710325718
# Epoch 9 and the loss is: 0.04686535522341728
# Epoch 9 and the loss is: 0.020362894982099533
# Epoch 9 and the loss is: 0.12813135981559753
# Epoch 9 and the loss is: 0.1793910562992096
# Epoch 9 and the loss is: 0.011265162378549576
# Epoch 9 and the loss is: 0.1649359166622162
# Epoch 9 and the loss is: 0.03010793775320053
# Epoch 9 and the loss is: 0.039973948150873184
# Epoch 9 and the loss is: 0.1279388666152954
# Epoch 9 and the loss is: 0.019904188811779022
# Epoch 9 and the loss is: 0.03773600235581398
# Epoch 9 and the loss is: 0.1295744925737381
# Epoch 9 and the loss is: 0.05386793985962868
# Epoch 9 and the loss is: 0.023582831025123596
# Epoch 9 and the loss is: 0.06652982532978058
# Epoch 9 and the loss is: 0.07547636330127716
# Epoch 9 and the loss is: 0.014016876928508282
# Epoch 9 and the loss is: 0.041277460753917694
# Epoch 9 and the loss is: 0.054517827928066254
# Epoch 9 and the loss is: 0.06511648744344711
# Epoch 9 and the loss is: 0.03287278488278389
# Epoch 9 and the loss is: 0.06326689571142197
# Epoch 9 and the loss is: 0.04032154381275177
# Epoch 9 and the loss is: 0.0036450806073844433
# Epoch 9 and the loss is: 0.04038579389452934
# Epoch 9 and the loss is: 0.2092166393995285
# Epoch 9 and the loss is: 0.004857126157730818
# Epoch 9 and the loss is: 0.07845442742109299
# Epoch 9 and the loss is: 0.10753839462995529
# Epoch 9 and the loss is: 0.004250014200806618
# Epoch 9 and the loss is: 0.02036069519817829
# Epoch 9 and the loss is: 0.06814655661582947
# Epoch 9 and the loss is: 0.0756426751613617
# Epoch 9 and the loss is: 0.045524537563323975
# Epoch 9 and the loss is: 0.06708289682865143
# Epoch 9 and the loss is: 0.16712021827697754
# Epoch 9 and the loss is: 0.03468363359570503
# Epoch 9 and the loss is: 0.014941095374524593
# Epoch 9 and the loss is: 0.018563978374004364
# Epoch 9 and the loss is: 0.04979711398482323
# Epoch 9 and the loss is: 0.11592414975166321
# Epoch 9 and the loss is: 0.04887610301375389
# Epoch 9 and the loss is: 0.08743774890899658
# Epoch 9 and the loss is: 0.06547924131155014
# Epoch 9 and the loss is: 0.01677982322871685
# Epoch 9 and the loss is: 0.019834447652101517
# Epoch 9 and the loss is: 0.007699020206928253
# Epoch 9 and the loss is: 0.13999103009700775
# Epoch 9 and the loss is: 0.07453012466430664
# Epoch 9 and the loss is: 0.05247936397790909
# Epoch 9 and the loss is: 0.2546561658382416
# Epoch 9 and the loss is: 0.024235256016254425
# Epoch 9 and the loss is: 0.07201655954122543
# Epoch 9 and the loss is: 0.07173704355955124
# Epoch 9 and the loss is: 0.03240060433745384
# Epoch 9 and the loss is: 0.09134170413017273
# Epoch 9 and the loss is: 0.10816057026386261
# Epoch 9 and the loss is: 0.024868354201316833
# Epoch 9 and the loss is: 0.048971984535455704
# Epoch 9 and the loss is: 0.011196929961442947
# Epoch 9 and the loss is: 0.18684935569763184
# Epoch 9 and the loss is: 0.04276397079229355
# Epoch 9 and the loss is: 0.058502186089754105
# Epoch 9 and the loss is: 0.19597254693508148
# Epoch 9 and the loss is: 0.13154152035713196
# Epoch 9 and the loss is: 0.00965697318315506
# Epoch 9 and the loss is: 0.08190058171749115
# Epoch 9 and the loss is: 0.04863055422902107
# Epoch 9 and the loss is: 0.04850179702043533
# Epoch 9 and the loss is: 0.06664807349443436
# Epoch 9 and the loss is: 0.046453990042209625
# Epoch 9 and the loss is: 0.03657687082886696
# Epoch 9 and the loss is: 0.06479781866073608
# Epoch 9 and the loss is: 0.05639658123254776
# Epoch 9 and the loss is: 0.20984895527362823
# Epoch 9 and the loss is: 0.038212455809116364
# Epoch 9 and the loss is: 0.02341778203845024
# Epoch 9 and the loss is: 0.03664831444621086
# Epoch 9 and the loss is: 0.18750688433647156
# Epoch 9 and the loss is: 0.022008003666996956
# Epoch 9 and the loss is: 0.1350569725036621
# Epoch 9 and the loss is: 0.1388324499130249
# Epoch 9 and the loss is: 0.02150273509323597
# Epoch 9 and the loss is: 0.036513522267341614
# Epoch 9 and the loss is: 0.1092769205570221
# Epoch 9 and the loss is: 0.029877908527851105
# Epoch 9 and the loss is: 0.01759159378707409
# Epoch 9 and the loss is: 0.03815203532576561
# Epoch 9 and the loss is: 0.016741042956709862
# Epoch 9 and the loss is: 0.016605662181973457
# Epoch 9 and the loss is: 0.026493240147829056
# Epoch 9 and the loss is: 0.0012889382196590304
# Epoch 9 and the loss is: 0.07784272730350494
# Epoch 9 and the loss is: 0.13139066100120544
# Epoch 9 and the loss is: 0.07135684043169022
# Epoch 9 and the loss is: 0.06235257536172867
# Epoch 9 and the loss is: 0.2658589780330658
# Epoch 9 and the loss is: 0.010416315868496895
# Epoch 9 and the loss is: 0.030094454064965248
# Epoch 9 and the loss is: 0.10911182314157486
# Epoch 9 and the loss is: 0.05107549577951431
# Epoch 9 and the loss is: 0.0421365462243557
# Epoch 9 and the loss is: 0.023808568716049194
# Epoch 9 and the loss is: 0.05880828574299812
# Epoch 9 and the loss is: 0.011841485276818275
# Epoch 9 and the loss is: 0.02889733947813511
# Epoch 9 and the loss is: 0.03416074439883232
# Epoch 9 and the loss is: 0.05944928526878357
# Epoch 9 and the loss is: 0.22032080590724945
# Epoch 9 and the loss is: 0.0679343193769455
# Epoch 9 and the loss is: 0.005903246346861124
# Epoch 9 and the loss is: 0.006006267387419939
# Epoch 9 and the loss is: 0.07907617837190628
# Epoch 9 and the loss is: 0.02611774392426014
# Epoch 9 and the loss is: 0.06086571142077446
# Epoch 9 and the loss is: 0.01569930836558342
# Epoch 9 and the loss is: 0.01599453017115593
# Epoch 9 and the loss is: 0.06259070336818695
# Epoch 9 and the loss is: 0.009646441787481308
# Epoch 9 and the loss is: 0.03641843423247337
# Epoch 9 and the loss is: 0.029303086921572685
# Epoch 9 and the loss is: 0.029850229620933533
# Epoch 9 and the loss is: 0.02867130935192108
# Epoch 9 and the loss is: 0.06872408837080002
# Epoch 9 and the loss is: 0.11274312436580658
# Epoch 9 and the loss is: 0.07634773850440979
# Epoch 9 and the loss is: 0.09511873871088028
# Epoch 9 and the loss is: 0.15322664380073547
# Epoch 9 and the loss is: 0.12982980906963348
# Epoch 9 and the loss is: 0.043895699083805084
# Epoch 9 and the loss is: 0.24192441999912262
# Epoch 9 and the loss is: 0.030773745849728584
# Epoch 9 and the loss is: 0.2586195766925812
# Epoch 9 and the loss is: 0.08075905591249466
# Epoch 9 and the loss is: 0.050854239612817764
# Epoch 9 and the loss is: 0.12040673196315765
# Epoch 9 and the loss is: 0.08356912434101105
# Epoch 9 and the loss is: 0.12021325528621674
# Epoch 9 and the loss is: 0.06950543075799942
# Epoch 9 and the loss is: 0.10694570094347
# Epoch 9 and the loss is: 0.05471329391002655
# Epoch 9 and the loss is: 0.17053943872451782
# Epoch 9 and the loss is: 0.12999293208122253
# Epoch 9 and the loss is: 0.022075168788433075
# Epoch 9 and the loss is: 0.012406774796545506
# Epoch 9 and the loss is: 0.09945698827505112
# Epoch 9 and the loss is: 0.1207384243607521
# Epoch 9 and the loss is: 0.07563262432813644
# Epoch 9 and the loss is: 0.014055866748094559
# Epoch 9 and the loss is: 0.09651626646518707
# Epoch 9 and the loss is: 0.35956671833992004
# Epoch 9 and the loss is: 0.14410945773124695
# Epoch 9 and the loss is: 0.13440650701522827
# Epoch 9 and the loss is: 0.049894146621227264
# Epoch 9 and the loss is: 0.10955113917589188
# Epoch 9 and the loss is: 0.023726776242256165
# Epoch 9 and the loss is: 0.08995791524648666
# Epoch 9 and the loss is: 0.1769605278968811
# Epoch 9 and the loss is: 0.07216788083314896
# Epoch 9 and the loss is: 0.04002927988767624
# Epoch 9 and the loss is: 0.015140954405069351
# Epoch 9 and the loss is: 0.07735905051231384
# Epoch 9 and the loss is: 0.16996321082115173
# Epoch 9 and the loss is: 0.03181852772831917
# Epoch 9 and the loss is: 0.13469266891479492
# Epoch 9 and the loss is: 0.0964614748954773
# Epoch 9 and the loss is: 0.05969979986548424
# Epoch 9 and the loss is: 0.03155737370252609
# Epoch 9 and the loss is: 0.17974458634853363
# Epoch 9 and the loss is: 0.09226299077272415
# Epoch 9 and the loss is: 0.04395408555865288
# Epoch 9 and the loss is: 0.12036088854074478
# Epoch 9 and the loss is: 0.05075085908174515
# Epoch 9 and the loss is: 0.1344403624534607
# Epoch 9 and the loss is: 0.07201286405324936
# Epoch 9 and the loss is: 0.04262346774339676
# Epoch 9 and the loss is: 0.034159332513809204
# Epoch 9 and the loss is: 0.0033238253090530634
# Epoch 9 and the loss is: 0.019031833857297897
# Epoch 9 and the loss is: 0.0465058907866478
# Epoch 9 and the loss is: 0.1096300408244133
# Epoch 9 and the loss is: 0.032663021236658096
# Epoch 9 and the loss is: 0.21965916454792023
# Epoch 9 and the loss is: 0.1660877764225006
# Epoch 9 and the loss is: 0.07751549780368805
# Epoch 9 and the loss is: 0.08957333117723465
# Epoch 9 and the loss is: 0.020518949255347252
# Epoch 9 and the loss is: 0.054382823407649994
# Epoch 9 and the loss is: 0.013011173345148563
# Epoch 9 and the loss is: 0.3327123522758484
# Epoch 9 and the loss is: 0.07211492210626602
# Epoch 9 and the loss is: 0.09432661533355713
# Epoch 9 and the loss is: 0.058647990226745605
# Epoch 9 and the loss is: 0.13095007836818695
# Epoch 9 and the loss is: 0.01891498826444149
# Epoch 9 and the loss is: 0.04255998507142067
# Epoch 9 and the loss is: 0.0885326936841011
# Epoch 9 and the loss is: 0.18147458136081696
# Epoch 9 and the loss is: 0.04843412712216377
# Epoch 9 and the loss is: 0.3154177665710449
# Epoch 9 and the loss is: 0.06596890836954117
# Epoch 9 and the loss is: 0.1404988169670105
# Epoch 9 and the loss is: 0.046063169836997986
# Epoch 9 and the loss is: 0.08002631366252899
# Epoch 9 and the loss is: 0.1457807570695877
# Epoch 9 and the loss is: 0.1521606743335724
# Epoch 9 and the loss is: 0.09182094037532806
# Epoch 9 and the loss is: 0.19966478645801544
# Epoch 9 and the loss is: 0.2330324649810791
# Epoch 9 and the loss is: 0.1549864262342453
# Epoch 9 and the loss is: 0.11735983192920685
# Epoch 9 and the loss is: 0.021327096968889236
# Epoch 9 and the loss is: 0.06890112161636353
# Epoch 9 and the loss is: 0.011761607602238655
# Epoch 9 and the loss is: 0.04439375177025795
# Epoch 9 and the loss is: 0.022267978638410568
# Epoch 9 and the loss is: 0.07974226027727127
# Epoch 9 and the loss is: 0.07800949364900589
# Epoch 9 and the loss is: 0.061422690749168396
# Epoch 9 and the loss is: 0.04110295698046684
# Epoch 9 and the loss is: 0.22676783800125122
# Epoch 9 and the loss is: 0.1794912964105606
# Epoch 9 and the loss is: 0.05603056028485298
# Epoch 9 and the loss is: 0.059947896748781204
# Epoch 9 and the loss is: 0.037585873156785965
# Epoch 9 and the loss is: 0.03155715391039848
# Epoch 9 and the loss is: 0.017753474414348602
# Epoch 9 and the loss is: 0.05759048834443092
# Epoch 9 and the loss is: 0.0939897745847702
# Epoch 9 and the loss is: 0.04485420510172844
# Epoch 9 and the loss is: 0.0890728086233139
# Epoch 9 and the loss is: 0.276972234249115
# Epoch 9 and the loss is: 0.015109425410628319
# Epoch 9 and the loss is: 0.04614003002643585
# Epoch 9 and the loss is: 0.044585611671209335
# Epoch 9 and the loss is: 0.10083181411027908
# Epoch 9 and the loss is: 0.10903612524271011
# Epoch 9 and the loss is: 0.09381681680679321
# Epoch 9 and the loss is: 0.2444029152393341
# Epoch 9 and the loss is: 0.12651461362838745
# Epoch 9 and the loss is: 0.0598762109875679
# Epoch 9 and the loss is: 0.16488559544086456
# Epoch 9 and the loss is: 0.03759131208062172
# Epoch 9 and the loss is: 0.03083690255880356
# Epoch 9 and the loss is: 0.04927230253815651
# Epoch 9 and the loss is: 0.25465676188468933
# Epoch 9 and the loss is: 0.17289969325065613
# Epoch 9 and the loss is: 0.11722983419895172
# Epoch 9 and the loss is: 0.026781346648931503
# Epoch 9 and the loss is: 0.05254125967621803
# Epoch 9 and the loss is: 0.12526310980319977
# Epoch 9 and the loss is: 0.19053180515766144
# Epoch 9 and the loss is: 0.2751782536506653
# Epoch 9 and the loss is: 0.10514766722917557
# Epoch 9 and the loss is: 0.09689132869243622
# Epoch 9 and the loss is: 0.0474373959004879
# Epoch 9 and the loss is: 0.11188633739948273
# Epoch 9 and the loss is: 0.10918690264225006
# Epoch 9 and the loss is: 0.0916089415550232
# Epoch 9 and the loss is: 0.038059819489717484
# Epoch 9 and the loss is: 0.05536510422825813
# Epoch 9 and the loss is: 0.0013589621521532536
# Epoch 9 and the loss is: 0.06305276602506638
# Epoch 9 and the loss is: 0.07948095351457596
# Epoch 9 and the loss is: 0.04062456637620926
# Epoch 9 and the loss is: 0.09225112199783325
# Epoch 9 and the loss is: 0.11923300474882126
# Epoch 9 and the loss is: 0.22551919519901276
# Epoch 9 and the loss is: 0.13288259506225586
# Epoch 9 and the loss is: 0.17833447456359863
# Epoch 9 and the loss is: 0.040272489190101624
# Epoch 9 and the loss is: 0.3167699873447418
# Epoch 9 and the loss is: 0.04732473939657211
# Epoch 9 and the loss is: 0.26827144622802734
# Epoch 9 and the loss is: 0.04323196038603783
# Epoch 9 and the loss is: 0.027668505907058716
# Epoch 9 and the loss is: 0.04528080299496651
# Epoch 9 and the loss is: 0.031429726630449295
# Epoch 9 and the loss is: 0.12719212472438812
# Epoch 9 and the loss is: 0.08865347504615784
# Epoch 9 and the loss is: 0.1561877578496933
# Epoch 9 and the loss is: 0.13471344113349915
# Epoch 9 and the loss is: 0.21460162103176117
# Epoch 9 and the loss is: 0.01013936847448349
# Epoch 9 and the loss is: 0.04345746338367462
# Epoch 9 and the loss is: 0.08310116827487946
# Epoch 9 and the loss is: 0.04280875250697136

# %%
# Save the model to disk (the pth-files will be submitted automatically together with your notebook)
# Set confirm=False if you do not want to be asked for confirmation before saving.
if not skip_training:
    tools.save_model(net, '3_resnet.pth', confirm=True)
# Out:
# Model saved to 3_resnet.pth.

# %%
if skip_training:
    net = ResNet(n_blocks, n_channels=16)
    tools.load_model(net, '3_resnet.pth', device)
# Out:
# Model loaded from 3_resnet.pth.

# %%
# Compute the accuracy on the test set
accuracy = compute_accuracy(net, testloader)
print('Accuracy of the network on the test images: %.3f' % accuracy)
n_blocks = sum(type(m) == Block for _, m in net.named_modules())
assert n_blocks == 6, f"Wrong number ({n_blocks}) of blocks used in the network."

assert accuracy > 0.9, "Poor accuracy ({:.3f})".format(accuracy)
print('Success')
# Out:
# Accuracy of the network on the test images: 0.919
# Success
